# %% [markdown]
# <a href="https://colab.research.google.com/github/ArshHp/DeepLearning_Fundamentals/blob/main/Transformers_Usage_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 43.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 44.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 21.8 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
import numpy as np
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This life will teach you all about <mask> .", top_k=2) #top_2 : Number of possibilities
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# [{'score': 0.051759976893663406,
#   'token': 21473,
#   'token_str': ' forgiveness',
#   'sequence': 'This life will teach you all about forgiveness.'},
#  {'score': 0.039329398423433304,
#   'token': 2512,
#   'token_str': ' yourself',
#   'sequence': 'This life will teach you all about yourself.'}]

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Arun and I work at Open Text in Bangalore, India site",
)
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# {'score': 0.4880588948726654, 'start': 30, 'end': 39, 'answer': 'Open Text'}

# %%
question_answerer(
    question="Where do I live?",
    context="My name is Arun and I work at Open Text in Bangalore, India site",
)
# Out:
# {'score': 0.6368165016174316, 'start': 43, 'end': 52, 'answer': 'Bangalore'}

# %%
question_answerer(
    question="Where is Bangalore?",
    context="My name is Arun and I work at Open Text in Bangalore, India site",
)
# Out:
# {'score': 0.9104217290878296, 'start': 54, 'end': 59, 'answer': 'India'}

# %%
question_answerer(
    question="Name any engineer from Open Text India center?",
    context="My name is Arun and I work at Open Text in Bangalore, India site",
)
# Out:
# {'score': 0.9963161945343018, 'start': 11, 'end': 15, 'answer': 'Arun'}

# %%
AEC_context="Only OBM events that are forwarded with an open lifecycle state are considered for the AEC workflow.OBM events that already have a cause or symptoms aren't considered by AEC.AEC uses a nonconfigurable time of 11 minutes and the timer increments every minute. Only events that appear within this time are considered for automatic correlation with each other.The AEC workflow tracks the maximum event creation time across all OBM monitoring solutions that forward events to OPTIC Data Lake. If an event creation time is older than 11 minutes compared to the maximum that has been seen, the event isn\'t considered by AEC. Therefore, the sequence in which you forward events are important.AEC is resilient to network latency and can process events even if their time alignment isn’t perfect. However, always ensure that the network latency doesn’t exceed 11 minutes.Ensure that OBM events have a valid type to be considered by AEC.Ensure that OBM events have a valid Node CI or Related CI assigned to them to be considered by AEC. Also, ensure that CI hints for CI resolution of OBM are configured.Ensure that the clocks are synchronized between the machines hosting, suite external OBM monitoring solutions, and the suite Kubernetes cluster. Although the clocks should be synchronized, the time zones can be different.Ensure that the global CI IDs are consistent in both OBM and OPTIC Data Layer if the topology is forwarded to OPTIC Data Lake and it\'s reconciled between OBM and OPTIC Data Layer."
question_answerer(
    question="What is the AEC events time window?",
    context=AEC_context
)
# Out:
# {'score': 0.8677862286567688, 'start': 209, 'end': 219, 'answer': '11 minutes'}

# %%
question_answerer(
    question="What all events would be considered for the AEC capability?",
    context=AEC_context
)
# Out:
# {'score': 0.5171869993209839,
#  'start': 5,
#  'end': 63,
#  'answer': 'OBM events that are forwarded with an open lifecycle state'}

# %%
question_answerer(
    question="What all the limitations with the AEC capability?",
    context=AEC_context
)
# Out:
# {'score': 0.006414320785552263,
#  'start': 0,
#  'end': 63,
#  'answer': 'Only OBM events that are forwarded with an open lifecycle state'}

# %%
question_answerer(
    question="Where I should use the AEC capability?",
    context=AEC_context
)
# Out:
# {'score': 0.015080596320331097,
#  'start': 472,
#  'end': 487,
#  'answer': 'OPTIC Data Lake'}

# %%
question_answerer(
    question="What is the latency with AEC capability?",
    context=AEC_context
)
# Out:
# {'score': 0.6360849738121033, 'start': 851, 'end': 861, 'answer': '11 minutes'}

# %%
# ?question_answerer

# %%
question_answerer(
    question="What is AEC?",
    context=AEC_context
)
# Out:
# {'score': 0.026432309299707413,
#  'start': 178,
#  'end': 219,
#  'answer': 'uses a nonconfigurable time of 11 minutes'}

# %%
question_answerer(
    question="Where is India ?",
    context=AEC_context
)
# Out:
# {'score': 0.21527054905891418,
#  'start': 472,
#  'end': 487,
#  'answer': 'OPTIC Data Lake'}

# %% [markdown]
# Summarization
#
# Use Case: Summarize the entire support ticket into a KB document

# %%
from transformers import pipeline

summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of 
    graduates in traditional engineering disciplines such as mechanical, civil, 
    electrical, chemical, and aeronautical engineering declined, but in most of 
    the premier American universities engineering curricula now concentrate on 
    and encourage largely the study of engineering science. As a result, there 
    are declining offerings in engineering subjects dealing with infrastructure, 
    the environment, and related issues, and greater concentration on high 
    technology subjects, largely supporting increasingly complex scientific 
    developments. While the latter is important, it should not be at the expense 
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other 
    industrial countries in Europe and Asia, continue to encourage and advance 
    the teaching of engineering. Both China and India, respectively, graduate 
    six and eight times as many traditional engineers as does the United States. 
    Other industrial countries at minimum maintain their output, while America 
    suffers an increasingly serious decline in the number of engineering graduates 
    and a lack of well-educated engineers.
"""
)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# [{'summary_text': ' America has changed dramatically during recent years . The number of engineering graduates in the U.S. has declined in traditional engineering disciplines such as mechanical, civil,    electrical, chemical, and aeronautical engineering . Rapidly developing economies such as China and India continue to encourage and advance the teaching of engineering .'}]

# %%
summarizer(
    """
    The document needs to be updated with a command (given below)  which checks whether the existing postgres server certificate contains subjectAlternativeName(SAN) or not before instructing the users to Update PostgreSQL database server certificate after OMT upgrade.

openssl x509 -text -in <Postgres server.crt> -noout | grep "Subject Alternative Name" 

https://docs.microfocus.com/doc/Containerized_Operations_Bridge/2022.05/Preupgradereqs

https://docs.microfocus.com/doc/Containerized_Operations_Bridge/2022.05/EnableTLSInPostgrSQL

Update PostgreSQL database server certificate after OMT upgrade

The usage of server certificates without subjectAlternativeName(SAN) extension is not supported in 2022.05. Matching the hostname by relying on checking the “Common Name” field is not supported. Any certificates not having a SAN need to be updated or recreated before upgrading to 2022.05 and the same must be used during the upgrade. For more details on the certificate requirement details, See Enable TLS in PostgreSQL. 
"""
)
# Out:
# [{'summary_text': ' The document needs to be updated with a command (given below) which checks whether the existing postgres server certificate contains subjectAlternativeName(SAN) or not before instructing the users to Update Postgres database server certificate after OMT upgrade . For more details on the certificate requirement details, See Enable TLS in Postgres .'}]

# %%
summarizer(
    """TECHNICAL PROBLEM DESCRIPTION: 

 

SOLUTION: I completed the migration on my own machine and gave the customer a step-by-step guide.

Throughout this migration, I followed the steps below:

 

I started by installing CDF 2021.11
https://svsartifactory.swinfra.net/artifactory/itom-buildoutput/cdf-daily-build/2021.11/ITOM_Platform_Foundation_Standard_2021.11.00223.zip

 

Then I deployed the opsb(opsbridge-suite-2.2.0+20211100.267) 
 

Next, installed NOM (nom-reporting-1.5.4+20211104.3.tgz-patch4 in mixed mode) in shared mode with the same namespace(opsb).
https://svsartifactory.swinfra.net/artifactory/itom-mvn-nom-release/com/microfocus/itom/helm/nom-helm-charts/1.5.4.20211104.3/nom-helm-charts-1.5.4.20211104.3.tgz

helm install n --namespace o -f /root/v/nom-reporting-values.yaml -f /root/v/nom-helm-charts/samples/shared-optic.yaml -f /root/nom/certificates.yaml /root/v/ nom-reporting-1.5.4+20211104.3.tgz -f /root/v/small-mixed.yaml

 

Now all pods are working fine with both opsb and NOM except for the monitoring pod which is related to opsb and is a known issue.
 

After that, we must update a secret for the same:
              ./gen_secrets.sh -n opsb-helm -c /root/migration/nom-helm-charts/charts/nom-reporting-1.5.4+20211104.3.tgz -u

 

Then the CDF has been upgraded from 2021.11.00223 to 2022.05.00204, completed successfully.
 

After that, I deployed the latest NOM chart (nom-1.6.0+20220500.304) in another namespace nom with crossnamespace scenario.
 

The nom related certificates (RE & RID) should be available in the opsb chart, and the opsb related certificates (RE & RID) should be updated.
                  ITOM Practitioner Portal (microfocus.com) 

Create a NOM user and group, assign the appropriate roles (superAdmin, di admin, and bvd admin), and update the nom secrets file with the itom-admin transport user password.
 

Next, upgrade the opsb chart from opsbridge-suite-2.2.0+20211100.26 to opsbridge-suite-2.3.0+20220500.528 and generate an ArtemisPV.yaml file for the omi-artemis pod that has the information listed below link.
 

Operations Bridge - Containerized Create PV for OBM | Micro Focus Documentation

 

If any further information required, please let me know.

 

MODIFIED FILES: (full path & exact source version, per version) 

 

AFFECTED PROGRAMS/SCRIPTS/LIBRARIES ETC: 
"""
)
# Out:
# [{'summary_text': ' The ITOM Practitioner Portal (microfocus.com) has been upgraded from 2021.11.00223 to 2022.05.00204 . The migration is a step-by-step migration to the ITOM platform . The steps below are outlined in the guide below .'}]

# %%
summarizer(   
    """
The Root cause appears to have been that OpsB Containerized omi-0 message bus hit its limit of 100 pages.
/opt/HP/BSM/log/wde> /opt/HP/BSM/opr/support/opr-jmsUtil.sh

Live Server: omi-artemis

Last Alive: Mon Aug 29 20:53:02 UTC 2022 (0 seconds ago)

As a result, the Message receiver component had to reject:
/opt/HP/BSM/log/wde> tail -200 opr-gateway.log

2022-08-29 20:40:56,649 [Activator] INFO  MsgReceiver.process(103) - Rejected new data due to overloaded event queue

We stopped the omi-0 OBM with opr-support-utils.sh -stopAll
Logged into the omi-artemis pod

kubectl exec -it omi-artemis-bcbc5d6f6-lxhz9 -n opsb-helm -c service bash
under /service/bus removed contents in each of the directories of  bindings  journal  large-messages  paging

We then deleted the pod

Then after it was deleted and back up we deleted the omi-0 pod

Upon the restart it was successful and event forwarding verified

"""
)
# Out:
# [{'summary_text': ' OpsB Containerized omi-0 message bus hit its limit of 100 pages . Message receiver component had to reject new data due to overloaded event queue . Root cause appears to have been that the message bus had to be re-loaded . We then deleted the pod with opr-support-utils.sh -stopAll-All-Rejection .'}]
