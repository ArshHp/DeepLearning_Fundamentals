# %% [markdown]
# <a href="https://colab.research.google.com/github/ArshHp/DeepLearning_Fundamentals/blob/main/Transformers_Usage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 48.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 60.6 MB/s eta 0:00:00

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis",device=0)
classifier("Food was amazing")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# [{'label': 'POSITIVE', 'score': 0.9998799562454224}]

# %%
classifier("Studying Data Science Transformers")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9543337821960449}]

# %%
classifier ("Hello @Shihai(George) Zhang I’m forwarding this ticket to platform support as the issue is with uploading of the images when the disk space is low. But the error message from the script says “invalid user name, password or network/proxy configuration” which is misleading and therefore the ask is to enhance the UploadImages.sh script to incorporate correct log messages for an upload failure due to disk pressure or other conditions.")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9989873766899109}]

# %%
question_answerer = pipeline("question-answering",device=0)
# question_answerer(
#     question="Who is Pradip?",
#     context="My name is Pradip and I work as Freelancer",
# )

question_answerer(
    question="Where does Pradip Work?",
    context="My name is Pradip and I work as Freelancer on Upwork",
)
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# {'score': 0.9836944937705994, 'start': 46, 'end': 52, 'answer': 'Upwork'}
